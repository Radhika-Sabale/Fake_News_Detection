# %% [markdown]
# # Prediction

# %% [markdown]
# ### Import and Load model

# %%
import pickle

#load model
with open("../model/model.pkl", "rb") as f:
    model = pickle.load(f)

#load vectorizer
with open("../model/vectorizer.pkl", "rb") as f:
    vectorizer = pickle.load(f)

print("Model and Vectorizer loaded successfully!")
# Out:
# Model and Vectorizer loaded successfully!

# %% [markdown]
# ### Preprocessing function

# %%
import re
import nltk

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

nltk.download('punkt')
nltk.download('stopwords')

stop_words = set(stopwords.words("english"))
stemmer = PorterStemmer()

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z]', ' ', text)
    words = word_tokenize(text)
    return " ".join([stemmer.stem(word) for word in words if word not in stop_words])
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Radhika
# [nltk_data]     Sabale\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Radhika
# [nltk_data]     Sabale\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Sample

# %%
# sample = ["government announces new law"]
sample = ["The government has released an official report on economic growth"]

sample_clean = [preprocess_text(sample[0])]
sample_tfidf = vectorizer.transform(sample_clean)
prediction = model.predict(sample_tfidf)

if prediction[0] == 0:
    print("Fake News")
else:
    print("Real News")
# Out:
# Real News
