# %% [markdown]
# # Text Preprocessing

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import nltk
import re

# %% [markdown]
# ### NLTK Resources and Tools

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Radhika
# [nltk_data]     Sabale\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Radhika
# [nltk_data]     Sabale\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Radhika
# [nltk_data]     Sabale\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# %% [markdown]
# ### Load Clean Dataset

# %%
df = pd.read_csv("../data/cleaned_news.csv")
df.head()
# Out:
#                                                title  \
# 0  Many 'lost' voters say they have found their c...
# 1  Iranian Revolutionary Guards commander, anothe...
# 2  Cambodian leader gets China's backing as West ...
# 3   Ex-KKK Grand Wizard: Maine Gov. Right To Call...
# 4  FINGER-WAGGING GRANNY HILLARY CLINTON Blows Up...
#
#                                                 text  label
# 0  WASHINGTON/NEW YORK (Reuters) - Ted Wade hasn’...      1
# 1  BEIRUT (Reuters) - A commander in Iran s elite...      1
# 2  PHNOM PENH (Reuters) - Cambodian Prime Ministe...      1
# 3  David Duke is perhaps one of the most notoriou...      0
# 4  Hillary Clinton shows her true colors here wit...      0

# %% [markdown]
# ### Combine Title and Text

# %%
df["content"] = df["title"] + " " + df["text"]
df = df[["content","label"]]
df.head()
# Out:
#                                              content  label
# 0  Many 'lost' voters say they have found their c...      1
# 1  Iranian Revolutionary Guards commander, anothe...      1
# 2  Cambodian leader gets China's backing as West ...      1
# 3   Ex-KKK Grand Wizard: Maine Gov. Right To Call...      0
# 4  FINGER-WAGGING GRANNY HILLARY CLINTON Blows Up...      0

# %% [markdown]
# ### Create Stop word List and Stemmer

# %%
stop_words = set(stopwords.words("english"))
stemmer = PorterStemmer()

# %% [markdown]
# ### Text Cleaning Function

# %%
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z]',' ',text)
    words = word_tokenize(text)
    filtered_words = []
    for word in words:
        if word not in stop_words:  
            filtered_words.append(stemmer.stem(word))
    return " ".join(filtered_words)

# %% [markdown]
# ### Preprocessing

# %%
df["processed_content"] = df["content"].apply(preprocess_text)
df.head()
# Out:
#                                              content  label  \
# 0  Many 'lost' voters say they have found their c...      1
# 1  Iranian Revolutionary Guards commander, anothe...      1
# 2  Cambodian leader gets China's backing as West ...      1
# 3   Ex-KKK Grand Wizard: Maine Gov. Right To Call...      0
# 4  FINGER-WAGGING GRANNY HILLARY CLINTON Blows Up...      0
#
#                                    processed_content
# 0  mani lost voter say found candid trump washing...
# 1  iranian revolutionari guard command anoth figh...
# 2  cambodian leader get china back west condemn c...
# 3  ex kkk grand wizard main gov right call black ...
# 4  finger wag granni hillari clinton blow activis...

# %%
df.to_csv("../data/preprocessed_news.csv", index=0)
print("Preprocessed Dataset Saved Successfully")
# Out:
# Preprocessed Dataset Saved Successfully
